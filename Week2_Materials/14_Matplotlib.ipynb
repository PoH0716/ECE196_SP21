# %% [markdown]
# ## Matplotlib

# %% [markdown]
# <div class="alert alert-success">
# <a href="https://matplotlib.org/" class="alert-link">Matplotlib</a> is a Python library that provides customizable static, animated, and interactive visualizations in Python.
# </div>

# %% [markdown]
# Read the <a href="https://matplotlib.org/tutorials/introductory/usage.html#sphx-glr-tutorials-introductory-usage-py">beginner's guide on Matplotlib</a> and more about its detailed <a href="https://matplotlib.org/users/index.html">documentation</a>.

# %% [markdown]
# 1. Basic plotting
#     * line plot
#     * scatter plot
#     * bar graph
# 2. Plot features
#     * title
#     * axis
#     * label
#     * legend
#     * tick
#     * marker
#     * grid
# 3. Subplots
# 4. Save
# 5. Plot examples

# %% [markdown]
# #### 1. Basic plotting
# Learn more about different plots <a href = "https://matplotlib.org/3.3.2/tutorials/introductory/sample_plots.html">here</a>.

# %% [markdown]
# Line plots
# `plt.plot`

# %%
import matplotlib.pyplot as plt
import numpy as np
# include the line below to display images in Jupyter Notebook
# %matplotlib inline

# %%
a = np.array([2,1,5,7,4,6,8,14,10,9,20,22])
plt.plot(a)
plt.show()

# %%
x = np.linspace(0, 5, 20)
y = np.linspace(0, 10, 20)
plt.plot(x, y, 'purple') # line
plt.plot(x, y, 'o')      # dots
plt.show()

# %% [markdown]
# Scatter plots
# `plt.scatter`

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = (30 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# Bar graphs
# `plt.bar`

# %%
car = ['Mercedes', 'BMW', 'Honda', 'Ford', 'Toyota', 'Nissan', 'Audi']
sales = [12, 10.5, 9, 15, 24, 6, 7.5]

plt.bar(car, sales)
plt.xlabel("Make")
plt.ylabel("Vehicles sold (in 10,000)")
plt.title("Number of Car Sales by Brand (2019)")
plt.show()

# %% [markdown]
# #### 2. Plot features
# <center><img src="../media/anatomy.png" width="600px"></center>

# %%
x = np.arange(0, 3 * np.pi, 0.25)
y_sin = np.sin(x)
y_cos = np.cos(x)

plt.plot(x, y_sin)
plt.plot(x, y_sin, 'o')
plt.plot(x, y_cos)
plt.plot(x, y_cos, 'x')
plt.xlabel('x axis label')
plt.ylabel('y axis label')
plt.xticks(np.arange(0, 11, 1))
plt.yticks(np.arange(-1., 1.25, 0.25))
plt.title('Sine and Cosine')
plt.legend(['sin_line', 'sin_mark', 'cos_line', 'cos_mark'], loc='lower left',
           bbox_to_anchor=(1.0, 0.7), frameon=True)
plt.grid()

plt.show()

# %% [markdown]
# #### 3. Subplots
# To learn more about plotting using fig and axes for subplots, refer to <a href="https://towardsdatascience.com/clearing-the-confusion-once-and-for-all-fig-ax-plt-subplots-b122bb7783ca">this article</a>.
# <center><img src="../media/big_picture.png" width="500px"></center>

# %%
x = np.arange(0, 3 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

# Set up a subplot grid that has height 2 and width 1,
# and set the first such subplot as active.
plt.subplot(2, 1, 1)

# Make the first plot
plt.plot(x, y_sin)
plt.title('Sine')

# Set the second subplot as active, and make the second plot.
plt.subplot(2, 1, 2)
plt.plot(x, y_cos)
plt.title('Cosine')

# Show the figure.
plt.show()

# %%
x = np.arange(0, 3 * np.pi, 0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

ax1.plot(x, y_sin)
ax1.set_title('Sine')

ax2.plot(x, y_cos)
ax2.set_title('Cosine')

# Show the figure.
plt.show()

# %% [markdown]
# #### 4. Save plots

# %%
# plt.savefig('<your_path>') # if you didn't initialize fig, ax
# fig.savefig('<your_path>') # if you initialized fig, ax

# %% [markdown]
# #### 5. Plot examples
# Read about how pandas and matplotlib can be used together in this <a href="https://realpython.com/pandas-plot-python/">article</a>.

# %%
##### different subplots using indexing #####
np.random.seed(19680801)
data = np.random.randn(2, 100)

fig, axs = plt.subplots(2, 2, figsize=(6, 6))
axs[0, 0].hist(data[0])
axs[1, 0].scatter(data[0], data[1])
axs[0, 1].plot(data[0], data[1])
axs[1, 1].hist2d(data[0], data[1])

plt.show()

# %%
##### 2D data represented by combined subplots with different span #####
# Generate normal distributed sample points in 2-D
x, y = np.random.multivariate_normal([0, 0], [[1, 1], [1, 2]], 3000).T
# Define subplot styles
fig = plt.figure(figsize=(6.5, 6.5))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
ax = fig.add_subplot(grid[:-1, 1:])
ax_x = fig.add_subplot(grid[-1, 1:])
ax_y = fig.add_subplot(grid[:-1, 0])
# Plot the data to subplots
ax.scatter(x, y, s=3, alpha=0.5)
ax_x.hist(x, 40, orientation='vertical')
ax_y.hist(y, 40, orientation='horizontal')
ax_x.invert_yaxis()
ax_y.invert_xaxis()
plt.show()

# %%
##### 3D plot #####
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = Axes3D(fig)
X = np.arange(-5, 5, 0.15)
Y = np.arange(-5, 5, 0.15)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='viridis')
plt.show()
